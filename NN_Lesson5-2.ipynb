# %%
from __future__ import print_function
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, SimpleRNN, LSTM, GRU
from tensorflow.keras import utils
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
print(tf.__version__)
# Out:
# 2.1.0

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for device in gpu_devices:
    tf.config.experimental.set_memory_growth(device, True)

# %%
# Построчное чтение
with open("Robinzon.txt", 'rb') as _in:
    lines = []
    for line in _in:
        line = line.strip().lower().decode("utf-8", "ignore")
        if len(line) == 0:
            continue
        lines.append(line)
text = " ".join(lines)
chars = set([c for c in text])
nb_chars = len(chars)

# %%
# Создание индекса символов и reverse mapping чтобы передвигаться между значениями numerical
# ID and a specific character. The numerical ID will correspond to a column
# ID и определенный символ. Numerical ID будет соответсвовать колонке
# число при использовании one-hot кодировки для представление входов символов
char2index = {c: i for i, c in enumerate(chars)}
index2char = {i: c for i, c in enumerate(chars)}

# %%
# для удобства выберете фиксированную длину последовательность 10 символов 
SEQLEN, STEP = 10, 1
input_chars, label_chars = [], []

# конвертация data в серии разных SEQLEN-length субпоследовательностей
for i in range(0, len(text) - SEQLEN, STEP):
    input_chars.append(text[i: i + SEQLEN])
    label_chars.append(text[i + SEQLEN])

# %%
# Вычисление one-hot encoding входных последовательностей X и следующего символа (the label) y
X = np.zeros((len(input_chars), SEQLEN, nb_chars), dtype=np.bool)
y = np.zeros((len(input_chars), nb_chars), dtype=np.bool)
for i, input_char in enumerate(input_chars):
    for j, ch in enumerate(input_char):
        X[i, j, char2index[ch]] = 1
    y[i, char2index[label_chars[i]]] = 1

# %%
# установка ряда метапамертров  для нейронной сети и процесса тренировки
BATCH_SIZE, HIDDEN_SIZE = 32, 256
NUM_ITERATIONS = 22 # 25 должно быть достаточно
NUM_EPOCHS_PER_ITERATION = 2
NUM_PREDS_PER_EPOCH = 200

# %%
'''
Создание очень простой рекуррентной нейронной сети. В ней будет один реккурентный закодированный входной слой.
За ним последует полносвязный слой связанный с набором возможных следующих символов, 
которые конвертированы в вероятностные результаты через стандартную softmax активацию 
с multi-class cross-encoding loss функцию ссылающуются на предсказание one-hot encoding лейбл символа
'''
model = Sequential()
model.add(
    LSTM(  # вы можете изменить эту часть на LSTM или SimpleRNN, чтобы попробовать альтернативы
        HIDDEN_SIZE,
        return_sequences=False,
        input_shape=(SEQLEN, nb_chars),
        unroll=True
    )
)
model.add(Dense(nb_chars))
model.add(Activation("softmax"))
model.compile(loss="categorical_crossentropy", optimizer="adam")  #  rmsprop

# %%
# Выполнение серий тренировочных и демонстрационных итераций 
for iteration in range(NUM_ITERATIONS):
    # для каждой итерации запуск передачи данных в модель 
    print("=" * 50)
    print("Итерация #: %d" % (iteration))
    model.fit(X, y, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS_PER_ITERATION)

    # Select a random example input sequence.
    test_idx = np.random.randint(len(input_chars))
    test_chars = input_chars[test_idx]

    # для числа шагов предсказаний использование текущей тренируемой модели 
    # конструирование one-hot encoding для тестирования input и добавление предсказания.
    print("Генерация из посева: %s" % (test_chars))
    print(test_chars, end="")
    for i in range(NUM_PREDS_PER_EPOCH):
        # здесь one-hot encoding.
        X_test = np.zeros((1, SEQLEN, nb_chars))
        for j, ch in enumerate(test_chars):
            X_test[0, j, char2index[ch]] = 1
        # осуществление предсказания с помощью текущей модели.
        pred = model.predict(X_test, verbose=0)[0]
        y_pred = index2char[np.argmax(pred)]
        # вывод предсказания добавленного к тестовому примеру 
        print(y_pred, end="")
        # инкрементация тестового примера содержащего предсказание
        test_chars = test_chars[1:] + y_pred
print()
# Out:
# ==================================================
# Итерация #: 0
# Train on 15839 samples
# Epoch 1/2
# 15839/15839 [==============================] - 2s 134us/sample - loss: 3.1105
# Epoch 2/2
# 15839/15839 [==============================] - 1s 90us/sample - loss: 2.6141
# Генерация из посева: устынном б
# устынном бо поробил ко оробил ко оробил ко оробил ко оробил ко оробил ко оробил ко оробил ко оробил ко оробил ко оробил ко оробил ко оробил ко оробил ко оробил ко оробил ко оробил ко оробил ко оробил ко оробил ==================================================
# Итерация #: 1
# Train on 15839 samples
# Epoch 1/2
# 15839/15839 [==============================] - 1s 91us/sample - loss: 2.3775
# Epoch 2/2
# 15839/15839 [==============================] - 1s 90us/sample - loss: 2.2384
# Генерация из посева: то не попа
# то не попалить в порего поробля на поробля на поробля на поробля на поробля на поробля на поробля на поробля на поробля на поробля на поробля на поробля на поробля на поробля на поробля на поробля на поробля на==================================================
# Итерация #: 2
# Train on 15839 samples
# Epoch 1/2
# 15839/15839 [==============================] - 1s 91us/sample - loss: 2.1259
# Epoch 2/2
# 15839/15839 [==============================] - 1s 90us/sample - loss: 2.0263
# Генерация из посева: олосья, уд
# олосья, уди в собе на острова к порабль о правили и с собел в собе на острова к порабль о правили и с собел в собе на острова к порабль о правили и с собел в собе на острова к порабль о правили и с собел в собе==================================================
# Итерация #: 3
# Train on 15839 samples
# Epoch 1/2
# 15839/15839 [==============================] - 1s 92us/sample - loss: 1.9315
# Epoch 2/2
# 15839/15839 [==============================] - 1s 90us/sample - loss: 1.8290
# Генерация из посева: их европей
# их европей корабль постовал в его дерь в поредном обнаружил стования постовал в его дерь в поредном обнаружил стования постовал в его дерь в поредном обнаружил стования постовал в его дерь в поредном обнаружил ==================================================
# Итерация #: 4
# Train on 15839 samples
# Epoch 1/2
# 15839/15839 [==============================] - 1s 91us/sample - loss: 1.7175
# Epoch 2/2
# 15839/15839 [==============================] - 1s 90us/sample - loss: 1.5984
# Генерация из посева:  острове.
#  острове. Как-то на острове приили и строве на острове приили и строве на острове приили и строве на острове приили и строве на острове приили и строве на острове приили и строве на острове приили и строве на о==================================================
# Итерация #: 5
# Train on 15839 samples
# Epoch 1/2
# 15839/15839 [==============================] - 1s 92us/sample - loss: 1.4712
# Epoch 2/2
# 15839/15839 [==============================] - 1s 90us/sample - loss: 1.3307
# Генерация из посева: зводить ог
# зводить ого превания за дождей в слобей корабль попалить в посте на острове. Как-то за нем постонил вернуться на острове. Как-то за нем постонил вернуться на острове. Как-то за нем постонил вернуться на острове==================================================
# Итерация #: 6
# Train on 15839 samples
# Epoch 1/2
# 15839/15839 [==============================] - 1s 91us/sample - loss: 1.1763
# Epoch 2/2
# 15839/15839 [==============================] - 1s 90us/sample - loss: 1.0168
# Генерация из посева: латку. Исп
# латку. Испанец расинаен, что на острове начали и сендав от разилить отправиться в привенить и поподноком строва тречить емо все жилья. Ногоразоя не начало отонько он расспазал селой, которое острова. Как отазат==================================================
# Итерация #: 7
# Train on 15839 samples
# Epoch 1/2
# 15839/15839 [==============================] - 1s 91us/sample - loss: 0.8556
# Epoch 2/2
# 15839/15839 [==============================] - 1s 90us/sample - loss: 0.7004
# Генерация из посева: у. Робинзо
# у. Робинзон посталил дильнию млегое острова. В один из дней к берегу пречал на мерего броствонной из декали ь себь провал с морого выерать в наду. В один из дней к берегу пречал на мерего броствонной из декали ==================================================
# Итерация #: 8
# Train on 15839 samples
# Epoch 1/2
# 15839/15839 [==============================] - 1s 92us/sample - loss: 0.5660
# Epoch 2/2
# 15839/15839 [==============================] - 1s 90us/sample - loss: 0.4461
# Генерация из посева: ался не ст
# ался не стрелять, начал с осторожностьи разводить огонь, обзавелся древегный моськой спасте острова Робинзон полил и дека, он субил его посадило делень. Потеро восмугилсяху котото у постенил карибению полодои о==================================================
# Итерация #: 9
# Train on 15839 samples
# Epoch 1/2
# 15839/15839 [==============================] - 1s 92us/sample - loss: 0.3517
# Epoch 2/2
# 15839/15839 [==============================] - 1s 90us/sample - loss: 0.2842
# Генерация из посева: ться домой
# ться домой, поэтому в содню. В коребый порека остров по морю. Огибая подводные скалы, Крузо отправиться вместе с ним в Гвинею. В недобрый час – 1 сентября 1659 года Робинзон нашел чернила и бумагу и некоторые н==================================================
# Итерация #: 10
# Train on 15839 samples
# Epoch 1/2
# 15839/15839 [==============================] - 1s 92us/sample - loss: 0.2413
# Epoch 2/2
# 15839/15839 [==============================] - 1s 91us/sample - loss: 0.2187
# Генерация из посева: еха. Робин
# еха. Робинзон понумал дотами. Последний он сушил на солнце, чтобы заготавливать изюм впрок. В цветущей зеленой долине Робинзон понумал дотами. Последний он сушил на солнце, чтобы заготавливать изюм впрок. В цве==================================================
# Итерация #: 11
# Train on 15839 samples
# Epoch 1/2
# 15839/15839 [==============================] - 1s 91us/sample - loss: 0.1926
# Epoch 2/2
# 15839/15839 [==============================] - 1s 91us/sample - loss: 0.1834
# Генерация из посева: ремени его
# ремени его родители умерли, дома его встретили сестры с детьми и другие родственники. Все с большим увлечением слушали невероятную историю Робинзон посталил дилень «деметруйся кросле погледнико он не смог спуст==================================================
# Итерация #: 12
# Train on 15839 samples
# Epoch 1/2
# 15839/15839 [==============================] - 1s 91us/sample - loss: 0.1719
# Epoch 2/2
# 15839/15839 [==============================] - 1s 90us/sample - loss: 0.1641
# Генерация из посева: редложил с
# редложил съесть убитых врагов, однако Крузо показал, что его экипаж взбунтовался и перешел на сторону «шайки негодяев». Он и два его товарищи пропали, испугались и собирались вернуться домой. Мужчины заготовили==================================================
# Итерация #: 13
# Train on 15839 samples
# Epoch 1/2
# 15839/15839 [==============================] - 1s 91us/sample - loss: 0.1579
# Epoch 2/2
# 15839/15839 [==============================] - 1s 90us/sample - loss: 0.1489
# Генерация из посева: бинзон наш
# бинзон нашел чернила и бумагу и некоторое время делал записи. Порою на меня нападало отчаяние, я испытывал смертельную тоску, чтобы побороть эти горькие чувства, я взял перо и попытался доказать себе самому, чт==================================================
# Итерация #: 14
# Train on 15839 samples
# Epoch 1/2
# 15839/15839 [==============================] - 1s 91us/sample - loss: 0.1466
# Epoch 2/2
# 15839/15839 [==============================] - 1s 90us/sample - loss: 0.1359
# Генерация из посева:  собой на
#  собой на охоту в качестве жертвы, чтобы вдвоем выбраться на свободу. Однако через четыре мили «разъяренный вал» перевернул их судно. Робинзон понумал да пособел домн глабым. Дло допали. Посерь восемь лет назад==================================================
# Итерация #: 15
# Train on 15839 samples
# Epoch 1/2
# 15839/15839 [==============================] - 1s 92us/sample - loss: 0.1360
# Epoch 2/2
# 15839/15839 [==============================] - 1s 91us/sample - loss: 0.1352
# Генерация из посева: ола дерева
# ола дерева. Крузо поставил в лодке мачту с парусом. Наступил двадцать среб, отостел декаби,  острове. По пути Крузо поихал солал ие на соладе. Робинзон построил себе палатку из паруса и жердей, окружив ее оград==================================================
# Итерация #: 16
# Train on 15839 samples
# Epoch 1/2
# 15839/15839 [==============================] - 1s 93us/sample - loss: 0.1261
# Epoch 2/2
# 15839/15839 [==============================] - 1s 91us/sample - loss: 0.1262
# Генерация из посева: ой корабля
# ой корабля. Мужчины за месяц сделали пирогу из ствола кедрового дерева. Ему удалось спастись. Робинзон посетил корабль дал течь. Проходившее мимо судно бросило им шлюпку, и к вечеру им удалось спастись. Робинзо==================================================
# Итерация #: 17
# Train on 15839 samples
# Epoch 1/2
# 15839/15839 [==============================] - 1s 91us/sample - loss: 0.1222
# Epoch 2/2
# 15839/15839 [==============================] - 1s 91us/sample - loss: 0.1186
# Генерация из посева: час – 1 се
# час – 1 сентября 1651 года Робинзон понилает, что их корабль попал в струю морского течения, уносившего его все дальше. Однако вскоре течение ослабело и Робинзону было плохо и страшно от сильной качки. Он тысяч==================================================
# Итерация #: 18
# Train on 15839 samples
# Epoch 1/2
# 15839/15839 [==============================] - 1s 92us/sample - loss: 0.1176
# Epoch 2/2
# 15839/15839 [==============================] - 1s 92us/sample - loss: 0.1187
# Генерация из посева: дкой полян
# дкой полянке на скате высокого роста, отлично сложенный, руки и ноги были мусколисчые тег, подцоваловдети и у поты, на котором отмечал зарубками дни. Вместе с вещами герой с корабля перевез двух кошек и собаку,==================================================
# Итерация #: 19
# Train on 15839 samples
# Epoch 1/2
# 15839/15839 [==============================] - 1s 94us/sample - loss: 0.1162
# Epoch 2/2
# 15839/15839 [==============================] - 1s 92us/sample - loss: 0.1141
# Генерация из посева:  он смог п
#  он смог позволить себе отделить часть зерна на еду. После сильного землетрясения Робинзона на острове. По пути Крузо поймал молодого попугая, которого впоследствии по корабельному делу, что очень пригодилось г==================================================
# Итерация #: 20
# Train on 15839 samples
# Epoch 1/2
# 15839/15839 [==============================] - 1s 94us/sample - loss: 0.1079
# Epoch 2/2
# 15839/15839 [==============================] - 1s 91us/sample - loss: 0.1064
# Генерация из посева:  людей. Оп
#  людей. Опасаясь, что его товарища об окружающих землях и их обитателях – на одина дажи с вречниись на нем. Порежда ражия герей однади, Робинзон получил доступ к его трюму. На берегу герой обнаружил диких голуб==================================================
# Итерация #: 21
# Train on 15839 samples
# Epoch 1/2
# 15839/15839 [==============================] - 1s 92us/sample - loss: 0.1078
# Epoch 2/2
# 15839/15839 [==============================] - 1s 91us/sample - loss: 0.1036
# Генерация из посева:  и передум
#  и передумал. Робинзон познакомился с почтенным пожилым капитаном. Новый знакомый предложил съесть убитых врагов, однако Крузо показал, что как-то у их острова разбился корабль с помощью вставших на сторону «ша

# %% [markdown]
# #### 17. Робинзон понимает, что их корабль попал в струю морского течения, уносившего его все дальше. Однако вскоре течение ослабело и Робинзону было плохо и страшно от сильной качки.
